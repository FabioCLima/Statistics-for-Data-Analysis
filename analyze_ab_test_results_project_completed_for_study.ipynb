# %% [markdown]
# # Analyze A/B Test Results
#
# This project will ensure you have mastered the subjects covered in the Hypothesis Testing lessons.  The hope is to have this project be as comprehensive of these topics as possible.  Good luck!
#
# Corresponding with this notebook is a slide deck where you will need to update all the portions in red.  Completing the notebook will provide all the results needed for the slides.  **Correctly completing the slides is a required part of the project.**
#
# ## Table of Contents
# - [Introduction](#intro)
# - [Part I - Descriptive Statistics](#descriptive)
# - [Part II - Probability](#probability)
# - [Part III - Experimentation](#experimentation)
#
#
# <a id='intro'></a>
# ### Introduction
#
# A/B tests are very commonly performed by data analysts and data scientists.  For this project, you will be working to understand the results of an A/B test run by an e-commerce website.  Your goal is to work through this notebook to help the company understand if they should implement the new page, keep the old page, or perhaps run the experiment longer to make their decision.
#
# **As you work through this notebook, follow along in the classroom and answer the corresponding quiz questions associated with each question.** The labels for each classroom concept are provided for each question.  This will assure you are on the right track as you work through the project, and you can feel more confident in your final submission meeting the criteria.  As a final check, assure you meet all the criteria on the rubric.
#
# <a id='descriptive'></a>
# #### Part I - Descriptive Statistics
#
# To get started, let's import our libraries.

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

random.seed(0)

# %% [markdown]
# For all questions in `Part I` notice links to [pandas documentation](https://pandas.pydata.org/) are provided to assist with answering the questions.  Though there are other ways you could solve the questions, the documentation is provided to assist you with one fast way to find the answer to each question.
#
#
# `a)` Now, read in the `ab_data.csv` data. Store it in `df`. Read in the dataset and take a look at the top few rows here. **This question is completed for you**.

# %%
df = pd.read_csv('ab_data.csv')
df.head()

# %% [markdown]
# `b)` Use the below cell to find the number of rows in the dataset. [Helpful pandas link - `Dataframe.shape`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html#pandas.DataFrame.shape)

# %%
df.shape

# %% [markdown]
# `c)` The proportion of users converted.  [Helpful  Pandas Link - `Dataframe.mean`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html)

# %%
df["converted"].mean()

# %% [markdown]
# `d)` Do any of the rows have missing values? [Helpful Pandas Link - `Dataframe.isnull`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isnull.html) and [Helpful Pandas Link- `Dataframe.sum`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sum.html)

# %%
df.isnull().sum()

# %% [markdown]
# `e)` How many customers are from each country? Build a bar chart to show the count of visits from each country.

# %%
df["country"].value_counts()

# %%
# bar chart of results - this part is done for you
df["country"].value_counts().plot(kind="bar")
plt.title("Number of Visits From Each Country")
plt.ylabel("Count of Visits")
plt.show();

# %% [markdown]
# `f)` Recognize that all of your columns are of a **categorical data type** with the exception of one.  Which column is not **categorical**? [Helpful Pandas Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html)

# %%
df.info()

# %% [markdown]
# `g)` What are the possible values of the `converted` column?  Does it make sense that these values are the only possible values? Why or why not?
#
# **Here you can use one of the functions you used in an earlier question**.

# %%
df["converted"].unique()

# %% [markdown]
# <a id='probability'></a>
# #### Part II - Probability
#
# Now that you have had a chance to learn more about the dataset, let's look more at how different factors are related to `converting`.
#
# `a)` What is the probability of an individual converting regardless of the page they receive or the country they are from? Simply, what is the chance of conversion in the dataset?

# %%
df["converted"].mean()

# %% [markdown]
# `b)` Given that an individual was in the `control` group, what is the probability they converted? **This question is completed for you**

# %%
df.query('group == "control"')["converted"].mean()

# %% [markdown]
# `c)` Given that an individual was in the `treatment` group, what is the probability they converted?

# %%
df.query('group == "treatment"')["converted"].mean()

# %% [markdown]
# `d)` Do you see evidence that the treatment is related to higher `converted` rates?

# %%
p_control = df.query('group == "control"')["converted"].mean()
p_treatment = df.query('group == "treatment"')["converted"].mean()
print(f"P(converted | control)   = {p_control:.4f}")
print(f"P(converted | treatment) = {p_treatment:.4f}")
print(f"Difference (treatment - control) = {p_treatment - p_control:.4f}")
print()
# Yes — treatment shows a higher conversion rate (~5pp above control).
# However, this alone is not sufficient to conclude causality;
# we need a formal hypothesis test to rule out random chance.

# %% [markdown]
# `e)` What is the probability that an individual was in the `treatment`?

# %%
(df["group"] == "treatment").mean()

# %% [markdown]
# `f)` What is the probability that an individual was from Canada `CA`?

# %%
(df["country"] == "CA").mean()

# %% [markdown]
# `g)` Given that an individual was in the `US`, what was the probability that they `converted`? **This question is completed for you**
#
# $P(\text{converted} == 1|\text{country} ==\text{"US"})$

# %%
df.query('country == "US"')["converted"].mean()

# %% [markdown]
# `h)` Given that an individual was in the `UK`, what was the probability that they `converted`?
#
# $P(\text{converted} == 1|\text{country} ==\text{"UK"})$

# %%
df.query('country == "UK"')["converted"].mean()

# %% [markdown]
# `i)` Do you see evidence that the `converted` rate might differ from one country to the next?

# %%
# Conversion rate by country
conversion_by_country = df.groupby("country")["converted"].mean()
print(conversion_by_country)
print()
# The rates vary across countries, suggesting a potential country effect.
# CA shows the highest rate, while US appears lowest among the three.
# A formal test would be needed to confirm statistical significance.

# %% [markdown]
# `j)` Consider the table below, fill in the conversion rates below to look at how conversion by country and treatment group vary.  The `US` column is done for you, and two methods for calculating the probabilities are shown - **COMPLETE THE REST OF THE TABLE**.  Does it appear that there could be an interaction between how country and treatment impact conversion?
#
# These two values that are filled in can be written as:
#
# $P(\text{converted} == 1|(\text{country} ==\text{"US" AND }\text{group} ==\text{"control"})) = 10.7\%$
#
# $P(\text{converted} == 1|(\text{country} ==\text{"US" AND }\text{group} ==\text{"treatment"})) = 15.8\%$
#
# |             | US          | UK          | CA          |
# | ----------- | ----------- | ----------- | ----------- |
# | Control     | 10.7%       |  %          |  %          |
# | Treatment   | 15.8%       |  %          |  %          |

# %%
# Method 1  - explicitly calculate each probability
print(
    df.query('country == "US" and group == "control" and converted == 1').shape[0]
    / df.query('country == "US" and group == "control"').shape[0]
)
print(
    df.query('country == "US" and group == "treatment" and converted == 1').shape[0]
    / df.query('country == "US" and group == "treatment"').shape[0]
)

# %%
# Method 2 - quickly calculate using `groupby`
df.query('country == "US"').groupby("group")["converted"].mean()

# %% [markdown]
# ##### Solution -- Complete the Table Here
#
# ```python
# # Full 2x3 table: conversion rate by country and group
# df.groupby(['country', 'group'])['converted'].mean().unstack().mul(100).round(1)
# ```
#
# |             | US    | UK    | CA    |
# | ----------- | ----- | ----- | ----- |
# | Control     | 10.7% | 10.2% |  9.4% |
# | Treatment   | 15.8% | 14.9% | 15.4% |
#
# **Interpretation:** The treatment group consistently converts at a higher rate than control in all three countries (~5 pp lift). The pattern is remarkably uniform, suggesting little country-treatment interaction.

# %% [markdown]
# Vamos analisar o comando de forma estruturada, como em uma revisão técnica de projeto.
#
# ---
#
# # 🔍 Snippet
#
# ```python
# df.groupby(['country', 'group'])['converted'].mean().unstack()
# ```
#
# ---
#
# # 1. `groupby(['country', 'group'])`
#
# ## 📌 O que faz
#
# Agrupa os dados por duas dimensões:
#
# * `country`
# * `group` (control vs treatment)
#
# Isso cria uma estrutura hierárquica (MultiIndex), equivalente a:
#
# > “Para cada combinação de país e grupo…”
#
# ---
#
# # 2. `['converted']`
#
# Seleciona a variável de interesse:
#
# * `converted` é binária (0/1)
# * representa conversão
#
# ---
#
# # 3. `.mean()`
#
# Calcula a média de `converted` dentro de cada grupo.
#
# ## 📌 Insight estatístico
#
# Como a variável é binária:
#
# > média = proporção de conversão (p̂)
#
# Então você obtém algo como:
#
# ```
# country  group
# US       control      0.120
#          treatment    0.135
# UK       control      0.115
#          treatment    0.130
# ```
#
# ---
#
# # 4. `.unstack()`
#
# ## 📌 O que faz
#
# Transforma o índice hierárquico em formato de tabela (pivot).
#
# * Move `group` para colunas
# * Mantém `country` como índice
#
# ## 📌 Resultado final:
#
# ```
# group     control   treatment
# country
# US         0.120       0.135
# UK         0.115       0.130
# ```
#
# 👉 Isso melhora muito a legibilidade para comparação.
#
# ---
#
# # 5. Interpretação (nível negócio)
#
# > “Qual é a taxa de conversão por país, separando controle e tratamento?”
#
# ---
#
# # 6. Convertendo para percentual (1 casa decimal)
#
# Agora vamos para a parte prática que você pediu.
#
# ## ✔ Forma direta
#
# ```python
# df.groupby(['country', 'group'])['converted'] \
#   .mean() \
#   .unstack() \
#   .mul(100) \
#   .round(1) \
#   .astype(str) + '%'
# ```
#
# ---
#
# ## ✔ Explicação passo a passo
#
# ### `.mul(100)`
#
# Converte proporção → percentual
#
# ```
# 0.135 → 13.5
# ```
#
# ---
#
# ### `.round(1)`
#
# Arredonda para 1 casa decimal
#
# ```
# 13.456 → 13.5
# ```
#
# ---
#
# ### `.astype(str) + '%'`
#
# Transforma em string formatada
#
# ```
# 13.5 → "13.5%"
# ```
#
# ---
#
# # 7. Resultado final esperado
#
# ```
# group     control   treatment
# country
# US         12.0%      13.5%
# UK         11.5%      13.0%
# ```
#
# ---
#
# # 8. Alternativa mais elegante (format)
#
# Se quiser algo mais “presentation-ready”:
#
# ```python
# result = df.groupby(['country', 'group'])['converted'].mean().unstack()
#
# result.applymap(lambda x: f"{x*100:.1f}%")
# ```
#
# ---
#
# # 9. Insight de nível sênior
#
# Esse tipo de tabela é essencial para:
#
# * detectar heterogeneidade por país
# * identificar onde o tratamento funciona melhor
# * levantar hipóteses (não confirmar ainda!)
#
# ⚠️ Mas atenção:
#
# * segmentação reduz tamanho de amostra
# * pode perder poder estatístico
#
# ---
#
# # 10. Resumo
#
# Esse comando:
#
# * calcula taxas de conversão
# * segmenta por país e grupo
# * organiza em formato comparável
# * e pode ser facilmente transformado em percentual
#
# ---
#
# Se quiser, posso te mostrar como transformar essa tabela em:
#
# * gráfico (barplot correto para A/B)
# * ou já conectar com teste estatístico por segmento
#
# Isso já é nível entrevista forte.

# %%
# Full 2x3 conversion table
df.groupby(["country", "group"])["converted"].mean().unstack().mul(100).round(1)

# %% [markdown]
# <a id='experimentation'></a>
# ### Part III - Experimentation
#
# Consider you need to make the decision just based on all the data provided.  If you want to assume that the control page is better unless the treatment page proves to be definitely better at a Type I error rate of 5%, you state your null and alternative hypotheses in terms of **$p_{control}$** and **$p_{treatment}$** as:
#
# $H_{0}: p_{control} >= p_{treatment}$
#
# $H_{1}: p_{control} < p_{treatment}$
#
# Which is equivalent to:
#
# $H_{0}: p_{treatment} - p_{control} <= 0$
#
# $H_{1}: p_{treatment} - p_{control} > 0$
#
#
# Where
# * **$p_{control}$** is the `converted` rate for the control page
# * **$p_{treatment}$** `converted` rate for the treatment page
#
# **Note for this experiment we are not looking at differences associated with country.**

# %% [markdown]
# Assume under the null hypothesis, $p_{treatment}$ and $p_{control}$ both have "true" success rates equal to the **converted** success rate regardless of page - that is $p_{treatment}$ and $p_{control}$ are equal. Furthermore, assume they are equal to the **converted** rate in `df` regardless of the page. **These are set in the first cell below.**<br><br>
#
# * Use a sample size for each page equal to the ones in `df`. **These are also set below.**  <br><br>
#
# * Perform the sampling distribution for the difference in `converted` between the two pages over 500 iterations of calculating an estimate from the null.  <br><br>
#
# * Use the cells below to provide the necessary parts of this simulation.
#
# If this doesn't make complete sense right now, don't worry - you are going to work through the problems below to complete this problem.  You can use **Quiz 4** in the classroom to make sure you are on the right track.<br><br>

# %% [markdown]
# `a)` The **convert rate** for $p_{treatment}$ under the null.  The **convert rate** for $p_{control}$ under the null. The sample size for the `control` and the sample size for the `treatment` are from the original dataset. **All of these values are set below, and set the stage for the simulations you will run for the rest of this section.**

# %%
p_control_treatment_null = df["converted"].mean()
n_treatment = df.query('group == "treatment"').shape[0]
n_control = df.query('group == "control"').shape[0]

# %% [markdown]
# `b)` Use the results from part `a)` to simulate `n_treatment` transactions with a convert rate of `p_treatment_null`.  Store these $n_{treatment}$ 1's and 0's in a `list` of **treatment_converted**.  It should look something like the following (the 0's and and 1's **don't** need to be the same):
#
# `[0, 0, 1, 1, 0, ....]`

# %%
treatment_converted = list(np.random.binomial(1, p_control_treatment_null, n_treatment))
print(f"Simulated {len(treatment_converted)} treatment observations")
print("First 10:", treatment_converted[:10])

# %% [markdown]
# `c)` Use the results from part `a)` to simulate `n_control` transactions with a convert rate of `p_control_null`.  Store these $n_{treatment}$ 1's and 0's in a `list` of **control_converted**.  It should look something like the following (the 0's and and 1's **don't** need to be exactly the same):
#
# `[0, 0, 1, 1, 0, ....]`

# %%
control_converted = list(np.random.binomial(1, p_control_treatment_null, n_control))
print(f"Simulated {len(control_converted)} control observations")
print("First 10:", control_converted[:10])

# %% [markdown]
# `d)` Find the estimate for $p_{treatment}$ - $p_{control}$ under the null using the simulated values from part `(b)` and `(c)`.

# %%
p_treatment_sim = np.mean(treatment_converted)
p_control_sim = np.mean(control_converted)
p_diff_sim = p_treatment_sim - p_control_sim
print(f"p_treatment (sim) = {p_treatment_sim:.4f}")
print(f"p_control   (sim) = {p_control_sim:.4f}")
print(f"p_diff      (sim) = {p_diff_sim:.4f}")

# %% [markdown]
# `e)` Simulate 500 $p_{treatment}$ - $p_{control}$ values using this same process as `b)`- `d)` similarly to the one you calculated in parts **a. through g.** above.  Store all 500 values in an numpy array called **p_diffs**.  This array should look similar to the below **(the values will not match AND this will likely take a bit of time to run)**:
#
# `[0.001, -0.003, 0.002, ...]`

# %%
p_diffs = []
for _ in range(500):
    # simulate treatment and control under the null
    treatment_converted = np.random.binomial(1, p_control_treatment_null, n_treatment)
    control_converted = np.random.binomial(1, p_control_treatment_null, n_control)

    # calculate each group's rate under the null
    p_treat_null = treatment_converted.mean()
    p_ctrl_null = control_converted.mean()

    # store the difference
    p_diffs.append(p_treat_null - p_ctrl_null)

p_diffs = np.array(p_diffs)
print(f"p_diffs shape: {p_diffs.shape}")
print(f"First 5 values: {p_diffs[:5].round(4)}")

# %% [markdown]
# `f)` Plot a histogram of the **p_diffs**.  Does this plot look like what you expected?  Use the matching problem in the classroom to assure you fully understand what was computed here.

# %%
p_diffs_series = pd.Series(p_diffs)
p_diffs_series.hist(bins=30, edgecolor="black", color="steelblue")
plt.axvline(
    x=obs_diff,
    color="red",
    linestyle="--",
    linewidth=2,
    label=f"Observed diff = {obs_diff:.4f}",
)
plt.title("Sampling Distribution of $p_{treatment} - p_{control}$ Under $H_0$")
plt.xlabel("$p_{treatment} - p_{control}$")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# The distribution is approximately Normal and centered around 0,
# consistent with the Central Limit Theorem under H0 (no difference between groups).

# %% [markdown]
# `g)` What proportion of the **p_diffs** are greater than the difference observed between `treatment` and `control` in `df`?

# %%
# Observed difference in the actual data
obs_diff = (
    df.query('group == "treatment"')["converted"].mean()
    - df.query('group == "control"')["converted"].mean()
)

# p-value: proportion of simulated diffs MORE extreme than the observed
p_value = (p_diffs > obs_diff).mean()

print(f"Observed difference: {obs_diff:.4f}")
print(f"p-value: {p_value:.4f}")

# %% [markdown]
# `h)` In words, explain what you just computed in part `g)`  What is this value called in scientific studies?  What does this value mean in terms of whether or not there is a difference between the new and old pages using our Type I error rate of 0.05?

# %% [markdown]
# **Answer:**
#
# In part `g)` we calculated the **p-value** — the proportion of simulated differences under $H_0$ that were *at least as large* as the observed difference.
#
# - **Observed difference:** ~0.050 (treatment converts ~5 pp more than control)
# - **p-value ≈ 0.0** — none of the 500 simulations under $H_0$ produced a difference this large by random chance alone.
#
# **Conclusion:** With a Type I error rate of $\alpha = 0.05$, we **reject $H_0$**.
#
# The data provide strong evidence that the treatment page leads to a statistically significantly higher conversion rate than the control page. The p-value is well below 0.05, meaning it is extremely unlikely that this difference arose by chance if the pages were truly equivalent.

# %% [markdown]
# <a id='finalcheck'></a>
# ## Final Check!
#
# Congratulations!  You have reached the end of the A/B Test Results project!  You should be very proud of all you have accomplished!
#
# > **Tip**: Once you are satisfied with your work here, check over your notebook to make sure that it satisfies all the specifications mentioned in the rubric. You should also probably remove all of the "Hints" and "Tips" like this one so that the presentation is as polished as possible.
#
#
# <a id='submission'></a>
# ## Submission
#
# Please follow the directions in the classroom to submit this notebook, as well as your completed slides.
